# %% [markdown]
# # Experiments — ML and scoring variants
#
# Use this notebook to try different weights, cluster counts, or models before codifying in `src/`.

# %%
import pandas as pd
from pathlib import Path

DATA = Path("../data")
df = pd.read_parquet(DATA / "processed" / "features.parquet") if (DATA / "processed" / "features.parquet").exists() else pd.DataFrame()
df.head()
